# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
clf = DecisionTreeClassifier(criterion='entropy', random_state=1234)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1234)

# %%
fig = plt.figure(figsize=(25, 20))
_ = tree.plot_tree(clf,
                      feature_names=iris.feature_names,
                      class_names=iris.target_names,
                      filled=True)

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file=None,
feature_names=iris.feater_names,
class_names=iris.target_names,
filled=true)

graph = graphviz.Source(dot_data, format='png')
graph
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      93         try:
# ---> 94             return self[key]
#      95         except KeyError:
#
# KeyError: 'feater_names'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12892/1909880108.py in <module>
#       1 import graphviz
#       2 dot_data = tree.export_graphviz(clf, out_file=None,
# ----> 3 feature_names=iris.feater_names,
#       4 class_names=iris.target_names,
#       5 filled=true)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      94             return self[key]
#      95         except KeyError:
# ---> 96             raise AttributeError(key)
#      97
#      98     def __setstate__(self, state):
#
# AttributeError: feater_names
